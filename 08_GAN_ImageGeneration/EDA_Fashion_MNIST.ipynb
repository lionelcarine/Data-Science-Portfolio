# %% [markdown]
# # 🧪 EDA - Fashion MNIST

# %%
# Installer numpy si nécessaire
import sys
# !{sys.executable} -m pip install --user numpy matplotlib seaborn tensorflow
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.datasets import fashion_mnist

# Charger les données
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# Nom des classes
class_names = [
    "T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
    "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"
]

print(f"Train shape: {x_train.shape}, Test shape: {x_test.shape}")
# Out:
# ...
#   Using cached matplotlib-3.10.3-cp310-cp310-win_amd64.whl (8.1 MB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
#   Using cached tensorflow-2.19.0-cp310-cp310-win_amd64.whl (375.7 MB)
# ...
#   Using cached fonttools-4.58.5-cp310-cp310-win_amd64.whl (2.2 MB)
# ...
#   Using cached kiwisolver-1.4.8-cp310-cp310-win_amd64.whl (71 kB)
# ...
#   Using cached contourpy-1.3.2-cp310-cp310-win_amd64.whl (221 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#   Using cached pandas-2.3.1-cp310-cp310-win_amd64.whl (11.3 MB)
# ...
#   Using cached grpcio-1.73.1-cp310-cp310-win_amd64.whl (4.3 MB)
# ...
#   Using cached absl_py-2.3.1-py3-none-any.whl (135 kB)
# ...
#   Using cached h5py-3.14.0-cp310-cp310-win_amd64.whl (2.9 MB)
# ...
#   Using cached requests-2.32.4-py3-none-any.whl (64 kB)
# ...
#   Using cached ml_dtypes-0.5.1-cp310-cp310-win_amd64.whl (209 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# ...
#   Using cached tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
# ...

# %%
# Exemple d’images
def plot_samples(images, labels, class_names, n=10):
    plt.figure(figsize=(15, 3))
    for i in range(n):
        plt.subplot(1, n, i+1)
        plt.imshow(images[i], cmap='gray')
        plt.title(class_names[labels[i]])
        plt.axis('off')
    plt.tight_layout()
    plt.show()

plot_samples(x_train, y_train, class_names)

# %%
# Répartition des classes
sns.countplot(x=y_train)
plt.title("Distribution des classes (Train)")
plt.xticks(ticks=np.arange(10), labels=class_names, rotation=45)
plt.show()

# %%
# Statistiques des pixels
print("Pixel min:", np.min(x_train), " - max:", np.max(x_train))
print("Moyenne:", np.mean(x_train), " - Écart-type:", np.std(x_train))
# Out:
# Pixel min: 0  - max: 255
# Moyenne: 72.94035223214286  - Écart-type: 90.02118235130519
